# %% [markdown]
# <a href="https://colab.research.google.com/github/Fathima-Rinsha-k/RNN/blob/main/web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

data=yf.download("TCS.NS",period="3mo")

print(data.head())
# Out:
# /tmp/ipython-input-262372539.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data=yf.download("TCS.NS",period="3mo")
# [*********************100%***********************]  1 of 1 completed
# Price             Close         High          Low         Open   Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# Date
# 2025-11-20  3088.651855  3108.000078  3082.071527  3091.794674  2700767
# 2025-11-21  3094.348145  3113.401674  3079.222958  3088.651652  4177037
# 2025-11-24  3085.115967  3122.142811  3075.098129  3101.616062  6703764
# 2025-11-25  3063.508789  3093.562543  3059.383825  3089.142887  2737920
# 2025-11-26  3106.428467  3121.258962  3061.348076  3063.115986  2508527

# %%
import requests
from bs4 import BeautifulSoup

#website
url="https://toscrope"
response = requests.get(url)
#parse html
soup =BeautifulSoup(response.text,"html.parser")

quotes =soup.find_all("span",class_="text")

for quote in quotes:
    print(quote.text)
